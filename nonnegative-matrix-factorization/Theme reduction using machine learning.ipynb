# %% [markdown]
# ## Theme reduction of user feedback comments using machine learning (NMF)

# %% [markdown]
# ### Overview:
#
# Built a theme reduction model which will identify the top themes appearing in the user feedback comments after their classification. Additionally, found out the top comments associated with the top themes.
#
# The model helps in identifying the topics which appear frequently specific for each class and hence the overall themes which occur for that class.

# %% [markdown]
# ## Code Index:
#
#
# ### 1. Theme reduction using machine learning for identifying themes in classified comments
#
#     1.1 Importing essential libraries
#
#     1.2 Implementing the theme reduction libraries and functions
#
#     1.3 Null handling function
#
#     1.4 Reading the data from the file
#
#     1.5 Cleaning the nulls from the data and exploring it
#
#     1.6 Lemmatization class using NLTK
#
#     1.7 Removing all the non alpha-numeric characters
#
#     1.8 Tf-IDF for vectorizing and tokenizing the text data and removing the stop words
#
#     1.9 Function responsible for displaying the top topics/themes
#
#     1.10 Implementing theme reduction using machine learning with NMF(Non-Negative Matrix Factorization)
#
#     1.11 Getting the top comments associated with the themes

# %% [markdown]
# ## Code:

# %% [markdown]
# ### 1.1 Importing all the essential libraries and functions

# %%
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"
import matplotlib.pyplot as plt
# %matplotlib inline
import re
import string
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ### 1.2 Importing the theme reduction libraries and functions

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF

# %% [markdown]
# ### 1.3 Null handling function

# %%
#Null cleaning function

def myfillna(series):
    if series.dtype is pd.np.dtype(float):
        return series.fillna('')
    elif series.dtype is pd.np.dtype(int):
        return series.fillna('')
    else:
        return series.fillna('NA')

# %% [markdown]
# ### 1.4 Reading the data from the file

# %%
testdata=pd.read_csv('xplatest.csv',encoding='latin')

# %% [markdown]
# ### 1.5 Cleaning the nulls from the dataset and exploring it

# %%
testdata=testdata.apply(myfillna)

# %%
testdata.isnull().sum()
# Out:
# environment               0
# rating                    0
# comment_text              0
# Sentiment                 0
# Bug_classifier            0
# UX_classifier             0
# Performance_classifier    0
# dtype: int64

# %%
testdata.shape
# Out:
# (28018, 7)

# %%
testdata
# Out:
#        environment  rating  \
# 0      0            3
# 1      0            5
# 2      1            2
# 3      1            4
# 4      0            5
# 5      0            4
# 6      0            5
# 7      0            1
# 8      0            2
# 9      0            5
# 10     0            5
# 11     0            4
# 12     0            5
# 13     0            2
# 14     0            2
# 15     0            5
# 16     0            5
# 17     0            5
# 18     0            5
# 19     0            5
# 20     0            5
# 21     0            5
# 22     0            4
# 23     0            2
# 24     0            5
# 25     0            5
# 26     0            4
# 27     0            4
# 28     0            5
# 29     0            5
# ...   ..           ..
# 27988  0            5
# 27989  0            5
# 27990  0            5
# 27991  0            5
# 27992  0            5
# 27993  0            5
# 27994  0            5
# 27995  0            5
# 27996  0            5
# 27997  0            1
# 27998  0            5
# 27999  0            5
# 28000  0            5
# 28001  0            2
# 28002  0            4
# 28003  0            5
# 28004  0            5
# 28005  0            4
# 28006  0            5
# 28007  0            5
# 28008  0            5
# 28009  0            5
# 28010  0            5
# 28011  0            5
# 28012  0            5
# 28013  0            2
# 28014  0            5
# 28015  0            4
# 28016  0            5
# 28017  0            5
#
#                                                                                                                                                                                                                                                                                                                                                         comment_text  \
# 0      Ever since the SAP integration happened the software runs much much much slower - particularly on the mobile device.Also - the hotel search brings in hotels that do not meet the search criteria.
# 1      Much easier than I expected. I suppose I felt a little intimidated by something new in the beginning.
# 2      This new version is TOO SLOW. Too many steps.
# 3      once you understand the process...it is pretty good.
# 4      Excellent turnaround time on getting bank confirmation. Application is easy to use.
# 5      Send reminders more frequently, and include # OF DAYS DUE
# 6      User friendly
# 7      There is no need to itemize the hotel receipt tax because it is being submitted as an attachment.
# 8      allocating expenses was awkward.  I still find the system clunky.
# 9      Your staff is very friendly and professional.
# 10     Great System!
# 11     sometimes the constraints of the system don't match the actual charges, and it can make entering data difficult. For instance, I recently had a matter where I paid a deposit to a hotel, and then the balance. The stay was for 2 days, but I couldn't add it up neatly the way the program requires, so I had to just make up amounts to match the charges.
# 12     Efficient system for submitting business travel expenses.
# 13     Link does not often work and issues having to re-input info
# 14     System is slow and challenging if it hangs up
# 15     Great product - Great helpdesk
# 16     Very user friendly
# 17     easy user friendly
# 18     Great program and user frielndly.
# 19     the expense system is easy to navigate. makes life much easier.
# 20     This is the easiest expense system I have ever used.
# 21     easy app to use. spoke to concur rep with an issue importing a receipt they were able to resolve my problem
# 22     had trouble with a rail expense and system messages were not clear as to how to handle.
# 23     system response time to very slow
# 24     Appears to be straight forward.
# 25     Great! No Problems.
# 26     Satisfied with the function of the reporting
# 27     To itemize for Hotel or not to itemize is unclear.
# 28     I liked the fact we had the receipt as part of the expenses
# 29     Mexico charges for hotel need to clarify how to show expenses
# ...                                                              ...
# 27988  Easy to use!
# 27989  EXCELENTE HERRAMIENTA
# 27990  good
# 27991  thank you!
# 27992  thanks
# 27993  Very user friendly
# 27994  quick and easy.
# 27995  so easy
# 27996  Thanks!
# 27997  very slow
# 27998  Easy to navigate.
# 27999  VERY GOOD
# 28000  Great tool!
# 28001  not user friendly
# 28002  Easy to use.
# 28003  Awesome software
# 28004  good
# 28005  great!
# 28006  Excellent!
# 28007  GREAT!
# 28008  Easy to use!
# 28009  ok
# 28010  Good application.
# 28011  Easy
# 28012  very satisfied
# 28013  Slow
# 28014  fast and easy
# 28015  awesome
# 28016  Great APP!
# 28017  awesome
#
#        Sentiment  Bug_classifier  UX_classifier  Performance_classifier
# 0      0.183333   0               0              0
# 1      0.012216   0               0              0
# 2      0.112121   0               0              1
# 3      0.475000   0               0              0
# 4      0.716667   0               0              0
# 5      0.158333   0               0              0
# 6      0.375000   0               0              0
# 7      0.000000   0               0              0
# 8     -0.600000   0               0              0
# 9      0.293750   0               0              0
# 10     1.000000   0               0              0
# 11    -0.166667   1               1              0
# 12     0.000000   0               0              0
# 13     0.000000   1               0              0
# 14     0.100000   0               0              1
# 15     0.800000   0               0              0
# 16     0.287500   0               0              0
# 17     0.404167   0               0              0
# 18     0.800000   0               0              0
# 19     0.316667   0               0              0
# 20     0.000000   0               0              0
# 21     0.466667   1               0              0
# 22    -0.125000   0               0              0
# 23    -0.390000   0               0              1
# 24     0.200000   0               0              0
# 25     1.000000   0               0              0
# 26     0.500000   0               0              0
# 27     0.000000   0               0              0
# 28     0.600000   0               0              0
# 29     0.000000   0               0              0
# ...         ...  ..              ..             ..
# 27988  0.541667   0               0              0
# 27989  0.000000   0               0              0
# 27990  0.700000   0               0              0
# 27991  0.000000   0               0              0
# 27992  0.200000   0               0              0
# 27993  0.287500   0               0              0
# 27994  0.383333   0               0              0
# 27995  0.433333   0               0              0
# 27996  0.250000   0               0              0
# 27997 -0.390000   0               0              1
# 27998  0.433333   0               0              0
# 27999  0.910000   0               0              0
# 28000  1.000000   0               0              0
# 28001  0.375000   0               1              0
# 28002  0.433333   0               0              0
# 28003  1.000000   0               0              0
# 28004  0.700000   0               0              0
# 28005  1.000000   0               0              0
# 28006  1.000000   0               0              0
# 28007  1.000000   0               0              0
# 28008  0.541667   0               0              0
# 28009  0.500000   0               0              0
# 28010  0.700000   0               0              0
# 28011  0.433333   0               0              0
# 28012  0.650000   0               0              0
# 28013 -0.300000   0               0              1
# 28014  0.316667   0               0              0
# 28015  1.000000   0               0              0
# 28016  1.000000   0               0              0
# 28017  1.000000   0               0              0
#
# [28018 rows x 7 columns]

# %% [markdown]
# ### 1.6 Lemmatization class using NLTK

# %%
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 
class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, articles):
        return [self.wnl.lemmatize(t) for t in word_tokenize(articles)]

# %% [markdown]
# ### 1.7 Removing all the non alpha-numeric characters

# %%
RE_PREPROCESS = r'\W+|\d+' #the regular expressions that matches all non-characters
testdata.comment_text = np.array( [ re.sub(RE_PREPROCESS, ' ', comment).lower() for comment in testdata.comment_text])

# %% [markdown]
# ### 1.8 Tf-IDF for vectorizing and tokenizing the text data and removing the stop words

# %%
no_features = 1000

#Vectorization
tfidf_vectorizer = TfidfVectorizer(tokenizer=LemmaTokenizer(),max_df=0.55, min_df=5, ngram_range=(1,2),max_features=no_features, stop_words='english',use_idf=True)
tfidf = tfidf_vectorizer.fit_transform(testdata[testdata.Bug_classifier==1].comment_text)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

#The reason being TF-IDF works best with NMF (Non-Negative Matrix Factorization)

# %%
tfidf_feature_names
# Out:
# ['ability',
#  'able',
#  'absolute',
#  'accept',
#  'acceptable',
#  'access',
#  'account',
#  'accurately',
#  'action',
#  'actual',
#  'actually',
#  'add',
#  'add expense',
#  'add receipt',
#  'added',
#  'adding',
#  'addition',
#  'additional',
#  'address',
#  'advance',
#  'affidavit',
#  'air',
#  'airfare',
#  'airline',
#  'allocate',
#  'allocated',
#  'allocation',
#  'allow',
#  'amex',
#  'android',
#  'annoying',
#  'anymore',
#  'ap',
#  'app',
#  'app doe',
#  'app doesn',
#  'app ha',
#  'app phone',
#  'app using',
#  'app wa',
#  'app work',
#  'appear',
#  'application',
#  'approval',
#  'approve',
#  'approved',
#  'apps',
#  'area',
#  'aren',
#  'aren t',
#  'ask',
#  'asked',
#  'asking',
#  'associate',
#  'attach',
#  'attach receipt',
#  'attached',
#  'attached receipt',
#  'attaching',
#  'attaching receipt',
#  'attachment',
#  'attempt',
#  'attendee',
#  'attendee list',
#  'audit',
#  'auditor',
#  'authorization',
#  'auto',
#  'automated',
#  'automatically',
#  'available',
#  'available receipt',
#  'away',
#  'awful',
#  'bad',
#  'best',
#  'better',
#  'big',
#  'bit',
#  'book',
#  'booked',
#  'booked concur',
#  'booking',
#  'booking fee',
#  'box',
#  'broken',
#  'browser',
#  'bug',
#  'buggy',
#  'bulk',
#  'business',
#  'business meal',
#  'business purpose',
#  'button',
#  'calculator',
#  'called',
#  'camera',
#  'capture',
#  'car',
#  'car rental',
#  'card',
#  'card transaction',
#  'case',
#  'cash',
#  'category',
#  'cause',
#  'caused',
#  'causing',
#  'cell',
#  'cell phone',
#  'certain',
#  'change',
#  'change expense',
#  'changed',
#  'charge',
#  'charge number',
#  'charged',
#  'check',
#  'checked',
#  'choice',
#  'choose',
#  'chrome',
#  'city',
#  'claim',
#  'clear',
#  'clearly',
#  'click',
#  'clicking',
#  'close',
#  'clunky',
#  'code',
#  'com',
#  'come',
#  'coming',
#  'comment',
#  'company',
#  'complete',
#  'complete expense',
#  'complete report',
#  'completed',
#  'completely',
#  'complex',
#  'complicated',
#  'computer',
#  'concur',
#  'concur app',
#  'concur com',
#  'concur doe',
#  'concur ha',
#  'concur s',
#  'concur suck',
#  'concur wa',
#  'confirmation',
#  'confusing',
#  'connect',
#  'connection',
#  'consistently',
#  'constant',
#  'constantly',
#  'consuming',
#  'contact',
#  'continue',
#  'continues',
#  'copy',
#  'corporate',
#  'corporate card',
#  'correct',
#  'corrected',
#  'correctly',
#  'cost',
#  'couldn',
#  'couldn t',
#  'couple',
#  'crash',
#  'crash time',
#  'crashed',
#  'crashed time',
#  'crashing',
#  'create',
#  'create report',
#  'created',
#  'creates',
#  'creating',
#  'credit',
#  'credit card',
#  'cumbersome',
#  'currency',
#  'current',
#  'currently',
#  'customer',
#  'd',
#  'daily',
#  'daily rate',
#  'data',
#  'date',
#  'day',
#  'day day',
#  'decimal',
#  'default',
#  'delay',
#  'delete',
#  'deleted',
#  'deposit',
#  'desk',
#  'desktop',
#  'despite',
#  'detach',
#  'device',
#  'did',
#  'did work',
#  'didn',
#  'didn t',
#  'diem',
#  'difference',
#  'different',
#  'different night',
#  'different rate',
#  'difficult',
#  'difficult use',
#  'difficulty',
#  'dinner',
#  'direct',
#  'directly',
#  'display',
#  'document',
#  'doe',
#  'doe allow',
#  'doe work',
#  'doesn',
#  'doesn t',
#  'doesnt',
#  'doesnt work',
#  'doing',
#  'doing report',
#  'dollar',
#  'don',
#  'don t',
#  'dont',
#  'double',
#  'download',
#  'drag',
#  'drop',
#  'drop list',
#  'duplicate',
#  'duplicate charge',
#  'duplicate entry',
#  'duplicate expense',
#  'e',
#  'e g',
#  'earlier',
#  'easier',
#  'easier use',
#  'easily',
#  'easy',
#  'easy use',
#  'edit',
#  'effort',
#  'email',
#  'emailed',
#  'emailed receipt',
#  'emailing',
#  'employee',
#  'end',
#  'ended',
#  'enter',
#  'entered',
#  'entering',
#  'entering expense',
#  'entire',
#  'entry',
#  'error',
#  'error message',
#  'especially',
#  'event',
#  'exactly',
#  'example',
#  'excel',
#  'exception',
#  'exchange',
#  'exchange rate',
#  'exist',
#  'existing',
#  'expense',
#  'expense app',
#  'expense available',
#  'expense did',
#  'expense hotel',
#  'expense item',
#  'expense receipt',
#  'expense report',
#  'expense type',
#  'expense wa',
#  'expenseit',
#  'experience',
#  'explain',
#  'explanation',
#  'extra',
#  'extremely',
#  'extremely slow',
#  'fact',
#  'fails',
#  'far',
#  'faster',
#  'feature',
#  'fee',
#  'field',
#  'figure',
#  'file',
#  'file receipt',
#  'filled',
#  'finally',
#  'finish',
#  'fix',
#  'fix issue',
#  'fixed',
#  'flag',
#  'flagged',
#  'flight',
#  'following',
#  'force',
#  'forced',
#  'foreign',
#  'forever',
#  'form',
#  'format',
#  'freeze',
#  'frequent',
#  'frequently',
#  'friendly',
#  'frustrating',
#  'function',
#  'functionality',
#  'future',
#  'g',
#  'gallery',
#  'gave',
#  'general',
#  'getting',
#  'getting error',
#  'given',
#  'giving',
#  'giving error',
#  'glitch',
#  'glitchy',
#  'going',
#  'good',
#  'got',
#  'great',
#  'guest',
#  'ha',
#  'ha changed',
#  'ha issue',
#  'ha taken',
#  'half',
#  'handle',
#  'hang',
#  'happen',
#  'happened',
#  'happy',
#  'hard',
#  'harder',
#  'hate',
#  'having',
#  'having issue',
#  'header',
#  'help',
#  'help desk',
#  'helpful',
#  'hit',
#  'home',
#  'hope',
#  'horrible',
#  'hotel',
#  'hotel charge',
#  'hotel different',
#  'hotel expense',
#  'hotel itemization',
#  'hotel rate',
#  'hotel receipt',
#  'hotel room',
#  'hotel stay',
#  'hotel wa',
#  'hour',
#  'hour complete',
#  'hour expense',
#  'huge',
#  'icon',
#  'id',
#  'image',
#  'image receipt',
#  'import',
#  'imported',
#  'importing',
#  'impossible',
#  'include',
#  'included',
#  'including',
#  'incorrect',
#  'indicate',
#  'individual',
#  'info',
#  'information',
#  'initial',
#  'input',
#  'instance',
#  'instead',
#  'instead having',
#  'instruction',
#  'interface',
#  'international',
#  'internet',
#  'intuitive',
#  'invoice',
#  'iphone',
#  'iphone app',
#  'isn',
#  'isn t',
#  'issue',
#  'issue concur',
#  'issue hotel',
#  'issue submitting',
#  'issue time',
#  'issue wa',
#  'item',
#  'itemization',
#  'itemization hotel',
#  'itemize',
#  'itemized',
#  'itemizing',
#  'itinerary',
#  'job',
#  'just',
#  'kept',
#  'kept crashing',
#  'kept getting',
#  'kept giving',
#  'kind',
#  'know',
#  'laptop',
#  'late',
#  'later',
#  'le',
#  'leaving',
#  'let',
#  'let submit',
#  'library',
#  'like',
#  'line',
#  'line item',
#  'link',
#  'list',
#  'list expense',
#  'little',
#  'load',
#  'loaded',
#  'loading',
#  'location',
#  'lodging',
#  'log',
#  'logging',
#  'login',
#  'long',
#  'longer',
#  'look',
#  'lost',
#  'lot',
#  'lot issue',
#  'lot time',
#  'love',
#  'm',
#  'main',
#  'major',
#  'make',
#  'make difficult',
#  'make sense',
#  'making',
#  'manager',
#  'manual',
#  'manually',
#  'match',
#  'matching',
#  'matter',
#  'maybe',
#  'meal',
#  'mean',
#  'menu',
#  'message',
#  'mile',
#  'mileage',
#  'mileage calculator',
#  'min',
#  'minute',
#  'missing',
#  'missing receipt',
#  'mobile',
#  'mobile app',
#  'mobile device',
#  'money',
#  'month',
#  'multi',
#  'multiple',
#  'multiple item',
#  'multiple receipt',
#  'multiple time',
#  'navigate',
#  'necessary',
#  'need',
#  'need better',
#  'need fix',
#  'needed',
#  'new',
#  'new expense',
#  'nice',
#  'night',
#  'night hotel',
#  'night stay',
#  'nightly',
#  'nightly rate',
#  'nightmare',
#  'non',
#  'number',
#  'obvious',
#  'ok',
#  'old',
#  'online',
#  'open',
#  'opened',
#  'option',
#  'order',
#  'overall',
#  'page',
#  'page receipt',
#  'paid',
#  'pain',
#  'painful',
#  'parking',
#  'password',
#  'past',
#  'payment',
#  'pc',
#  'pdf',
#  'penny',
#  'period',
#  'personal',
#  'phone',
#  'phone app',
#  'photo',
#  'pic',
#  'pick',
#  'picture',
#  'picture receipt',
#  'place',
#  'platform',
#  'plus',
#  'point',
#  'policy',
#  'poor',
#  'populate',
#  'possible',
#  'pre',
#  'pretty',
#  'previous',
#  'previously',
#  'price',
#  'problem',
#  'process',
#  'program',
#  'project',
#  'proper',
#  'properly',
#  'provide',
#  'provided',
#  'purchase',
#  'purchased',
#  'purpose',
#  'putting',
#  'question',
#  'quick',
#  'quite',
#  'rate',
#  'rate different',
#  'rate night',
#  'read',
#  'real',
#  'really',
#  'reason',
#  'receipt',
#  'receipt affidavit',
#  'receipt attach',
#  'receipt attached',
#  'receipt concur',
#  'receipt did',
#  'receipt doesn',
#  'receipt don',
#  'receipt email',
#  'receipt emailed',
#  'receipt error',
#  'receipt expense',
#  'receipt function',
#  'receipt gallery',
#  'receipt ha',
#  'receipt image',
#  'receipt item',
#  'receipt missing',
#  'receipt multiple',
#  'receipt phone',
#  'receipt picture',
#  'receipt receipt',
#  'receipt report',
#  'receipt time',
#  'receipt uploaded',
#  'receipt wa',
#  'receipt work',
#  'received',
#  'recognize',
#  'record',
#  'recurring',
#  'red',
#  'redo',
#  'refresh',
#  'reimbursement',
#  'rejected',
#  'related',
#  'reload',
#  'remove',
#  'rental',
#  'report',
#  'report doe',
#  'report error',
#  'report header',
#  'report returned',
#  'report submitted',
#  'report time',
#  'report wa',
#  'reporting',
#  'request',
#  'require',
#  'required',
#  'requirement',
#  'requires',
#  'reservation',
#  'resolve',
#  'resolve issue',
#  'resolved',
#  'response',
#  'response time',
#  'restart',
#  'resubmit',
#  'result',
#  'return',
#  'returned',
#  'review',
#  'right',
#  'room',
#  'round',
#  'round trip',
#  'rounding',
#  'route',
#  's',
#  'said',
#  'sap',
#  'save',
#  'save expense',
#  'save time',
#  'saved',
#  'saving',
#  'say',
#  'saying',
#  'scan',
#  'scanned',
#  'scanned receipt',
#  'screen',
#  'search',
#  'second',
#  'section',
#  'select',
#  'selected',
#  'selecting',
#  'selection',
#  'send',
#  'sense',
#  'sent',
#  'separate',
#  'separately',
#  'service',
#  'set',
#  'shouldn',
#  'shouldn t',
#  'showed',
#  'showing',
#  'sign',
#  'similar',
#  'simple',
#  'simpler',
#  'simply',
#  'single',
#  'site',
#  'size',
#  'slow',
#  'slow cumbersome',
#  'slow slow',
#  'slow took',
#  'small',
#  'software',
#  'solution',
#  'space',
#  'spend',
#  'spent',
#  'spent hour',
#  'split',
#  'st',
#  'star',
#  'start',
#  'started',
#  'state',
#  'stated',
#  'stay',
#  'step',
#  'stop',
#  'store',
#  'struggled',
#  'sub',
#  'submission',
#  'submit',
#  'submit expense',
#  'submit report',
#  'submitted',
#  'submitting',
#  'submitting expense',
#  'submitting report',
#  'successfully',
#  'suck',
#  'super',
#  'support',
#  'sure',
#  'sync',
#  't',
#  't add',
#  't allow',
#  't appear',
#  't attach',
#  't clear',
#  't come',
#  't know',
#  't let',
#  't make',
#  't match',
#  't receipt',
#  't upload',
#  't work',
#  'taken',
#  'taking',
#  'task',
#  'tax',
#  'taxi',
#  'team',
#  'tedious',
#  'tell',
#  'telling',
#  'terrible',
#  'th',
#  'thank',
#  'thanks',
#  'thing',
#  'think',
#  'thought',
#  'ticket',
#  'time',
#  'time consuming',
#  'time spent',
#  'time time',
#  'time trying',
#  'time use',
#  'time using',
#  'time wa',
#  'timely',
#  'tip',
#  'today',
#  'told',
#  'toll',
#  'ton',
#  'took',
#  'took hour',
#  'took minute',
#  'tool',
#  'total',
#  'transaction',
#  'transfer',
#  'travel',
#  'travel expense',
#  'traveler',
#  'tried',
#  'trip',
#  'trouble',
#  'try',
#  'trying',
#  'trying figure',
#  'twice',
#  'type',
#  'u',
#  'uber',
#  'uber receipt',
#  'ui',
#  'unable',
#  'understand',
#  'unless',
#  'unnecessary',
#  'update',
#  'upload',
#  'upload image',
#  'upload receipt',
#  'uploaded',
#  'uploaded receipt',
#  'uploading',
#  'uploading receipt',
#  'use',
#  'use app',
#  'use concur',
#  'used',
#  'user',
#  'user friendly',
#  'using',
#  'using mobile',
#  'usually',
#  'v',
#  'value',
#  've',
#  'vendor',
#  'verify',
#  'version',
#  'view',
#  'visa',
#  'visible',
#  'wa',
#  'wa able',
#  'wa error',
#  'wa unable',
#  'wait',
#  'waiting',
#  'want',
#  'wanted',
#  'warning',
#  'wasn',
#  'wasn t',
#  'waste',
#  'waste time',
#  'wasted',
#  'wasted time',
#  'way',
#  'way attach',
#  'way time',
#  'web',
#  'website',
#  'week',
#  'went',
#  'window',
#  'won',
#  'won t',
#  'work',
#  'work properly',
#  'work time',
#  'worked',
#  'working',
#  'worst',
#  'wouldn',
#  'wouldn t',
#  'wrong',
#  'year',
#  'yesterday',
#  'â',
#  'â â',
#  'ã',
#  'ã â']

# %% [markdown]
# ### 1.9 Function responsible for displaying the top topics

# %%
def reduce_themes(model, feature_names, documents, no_top_words, no_top_documents,countv):
    for topic_idx, topic in enumerate(model.components_):
        print('\033[1m' + 'Topic %d:' % (topic_idx) + "\033[0;0m")
        print ('\033[1m' + ' '.join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]) + "\033[0;0m")
        print(' ')
        top_doc_indices = np.argsort(model.transform(countv)[:,topic_idx] )[::-1][0:no_top_documents]
        for doc_index in top_doc_indices:
            print (documents[doc_index])
            print (' ')

no_topics = 20


#NMF is an equivalent for PCA but for text

# %% [markdown]
# ### 1.10 Implementing theme reduction using machine learning with NMF(Non-Negative Matrix Factorization)

# %%
nmf = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)

# %% [markdown]
# ### 1.11 Getting the top comments associated with the themes

# %%
documents = []
for i in testdata.comment_text:
    documents.append(i)
    
no_top_documents= 10
no_top_words = 10

reduce_themes(nmf, tfidf_feature_names, documents, no_top_words, no_top_documents,countv=tfidf)
# Out:
# Topic 0:
# receipt attach image attached receipt image attach receipt upload file attaching uploading
#
# this is my first exposure to this system it seems to work well once you get a little assistance in what the correct codes are for accounting purposes
#
# great application very easy to use
#
# if possible allow a range for reoccurring costs example toll feeswhen there is a expense of   zero a note should remove all warnings when a new itinerary is issued this should be indicated
#
# it s getting easier to use
#
# the itemization on hotels does not always work good and results in double work which is annoying
#
# would not calculate mileage several times had to close tab and return to expense report from main menu multiple times to complete report
#
# superb
#
# this is a complex and not exactly user friendly method
#
# once again lost expensit receipts and multiple crashes
#
# complicated how concur handles situations when breakfast is included in the room price
#
# Topic 1:
# work t work app work work time did work work properly doesnt work function doesnt tool
#
# i think it is still buggy
#
# the fax option never works anymore we get a transmission confirmation on our side but continues to say receipts are missing month after month i know that attaching the receipts electronically is easier for your side but not always as easy on our side why continue to offer faxing as an option if it doesn t work any more i really think this is just away to force our hand to do it the way that you want it not what is easier for us very frustrating
#
# when you finish one task the next task should be highlighted
#
# too convoluted process
#
# this is the most cumbersome unintuitive system imaginable
#
# hotel itemizations area real pain way too much effort to itemize all these receipts should be completely automated
#
# submitting initial expense report was confusing with duplicate entries hopefully the next time will flow smoother
#
# categories are not intuitive and lead to confusion and uncertainty uploading pdf receipts proved quite frustrating
#
# at first it was a little tough to use but it seems to be getting better and i m getting better at using your system
#
# send reminders more frequently and include of days due
#
# Topic 2:
# doesn t doesn t t work t allow allow app doesn field correct like
#
# when you finish one task the next task should be highlighted
#
# activity code does not connect to all hotel expenses had to add activity codes to hotel taxes etc very time consuming your app is very poor slow and buggy
#
# had issues with the hotel overcharge and subsequently a credit was issued there was an exception due to miss match of the expense amount and charge i contacted accounting operations for chrysler and the issue was resolved quickly by ms karolina polewka within a matter of hours excellent service by karolina thank you
#
# able to complete my expense report without issues
#
# personal expenses are unable to process very frustrating
#
# this is the most cumbersome unintuitive system imaginable
#
# approvals are super quick lately much appreciated
#
# horrible horrible website calling in and the support was good but it shouldn t be necessary to get help everytime you want to submit an expense report
#
# great
#
# send reminders more frequently and include of days due
#
# Topic 3:
# mobile mobile app app password uploading using use having web app doe
#
# not intuitive and very time consuming it took me one hour to do a simple expense report
#
#
#
# complicated and time consuming
#
# at first i wasn t happy using concur but now that i m getting more familiar it is saving me some time
#
# i could not press the submit button
#
# thank you
#
# terrible system i honestly hope another system will replace this when we spin
#
# not sure why but i had to attach my receipt like   times it kept showing the transaction requires a receipt even though i had attached multiple times and it was visible every time
#
# user friendly
#
# takes way to long many error messages
#
# Topic 4:
# slow slow slow buggy hour extremely slow took hour extremely took load click
#
# issue with currency and country of residence
#
# the taxi requirements are redundant we repeat ourselves three times
#
# very cumbersome kept giving errors with little explanation would not refesh screen when updating some fields so had to submit request multiple times to make it refresh the entries
#
# the integration between expenseit and concur could be improved some receipt images never transitioned properly
#
# don t pop up the travel portion on launch thanks
#
# took about   hours to complete report not sure why we have to break up the hotel into different line items for each night
#
# got it down to a science now
#
# caution error message still displayed warning to please attach a receipt for this expense type even after a receipt has been uploaded for the expense type
#
# airline hotel and car rental receipts are not consistently being uploaded to my expenses it makes it much more time consuming to complete the reports
#
# some errors but overall great
#
# Topic 5:
# suck concur suck concur picture just way tool change value major
#
# this is much easier to use than it used to be but it still takes some getting used to and isn t entirely intuitive
#
# hotel itemization field is a little confusing
#
# why does this have to be so time consuming
#
# it s very slow to view a receipt
#
# very confusing navigations for first time user
#
# not bad seemed to work well slightly confusing on entering the city information
#
# always takes me an hour no matter how may times i use the system
#
# receipts drop off or missing when you submit
#
# really no stars
#
# this software is a nightmare and im in it
#
# Topic 6:
# error error message message wa getting kept â getting error report error exist
#
# i do not like that the system creates reports for me
#
# can t split an expense into itemizations to be paid and unpaid my example i didn t want the company to pay for my alcoholic beverage that accompanied my meal while travelling for business but my meal beverage was all on one receipt no easy way to do this
#
# ã æ â ºã æ â ã æ â ã â â ã ë å½ã â â ã å â ã â å ã ë â ã â â ¹ã â å ã â â ã â â ã â â
#
# concur is the worst not user friendly at all
#
# best regards ã â â takezawa
#
# getting used to the format
#
# you omit certain key categories such as passport and visa fees which i must categorize as miscellaneous you omit room service which is commonly available in most hotels
#
# perfect app for expenses and easy to navigate
#
# very quick and easy to use and navigate
#
# really difficult reporting system
#
# Topic 7:
# hotel different night rate itemization fix hotel itemization different rate tax charge
#
# help resources are not easy to use and cannot find phone numbers to contact someone to talk with
#
# ã æ â ã â â ã æ â¼ã æ ë ã â â ã â â ã å¾å ã â å ã â â ã â â ã â ë ã â â ã â â ¹ã â â ã â â ã â â ã â â
#
# ã â â½
#
# i appreciate that concur reminded me to wait until my cc charges came in before submitting them
#
# receipts from mobile app are not matching up and in some cases with the wrong amounts this is not user friendly this new receipt option on the mobile app making travel very frustrating
#
# very easy to use and convenient
#
# easy to use
#
# your platform is not user friendly at all so confusing and painful to submit reports
#
# if i buy a ticket on your platform the bill should be auto loaded into my expenses list instead i have you email me the bill then i email it back to you twice to attche to my charges this is a huge waste of time
#
# had to call it   times
#
# Topic 8:
# doe doe work work app doe concur doe good submitted information anymore link
#
# for the web and today s coding abilities it feels clunky
#
# user friendly
#
# the concur application has become more difficult to use particularly the mobile app which seems to cause receipt images to be attached to the wrong receipts the automation which reads receipts as well as the feature that tries to match expenses to charges attempts to be helpful but ends up causing headaches
#
# thanks
#
# no instructions on how to do the per diem
#
# unable to see my own report history i had a report started in january couldn t find it today didn t know if accidently submitted before done this is just one example of many as to why being able to look at a person s own report history can be valuable to avoid errors
#
# love the app to take pictures of receipts
#
# slow slow slow
#
# add a meal option for other when you buy coffee or water at the airport
#
# this time i didn t face any problem for missing receipts like earlier thanks
#
# Topic 9:
# crashing kept crashing stop kept terrible android experience opened saying login
#
# reimbursement processing takes too long needs improvement
#
# it did not appear that you could attach multiple documents at the same time therefore each document had to be attached one at a time it would be easier if we could attach multiple documents at the same time
#
# na
#
# todo muy bien muchas gracias
#
# great system
#
# not easy to use accidentally created a second itinerary and it took a long time to figure out how to delete it
#
# menu selections are not always intuitive
#
# pretty simple to use
#
# sin comentarios
#
# rosemary wormke filled out most of my report jane sawer finalized my report
#
# Topic 10:
# issue having issue having issue submitting resolve wa resolved lot issue ui ha issue
#
# too many outages
#
# itemizing hotel receipts is a huge pain in the
#
# too cumbersome not very user friendly mileage has to be put in one by one which takes a lot of time especially whey rm s travel everyday to clients
#
# can t split an expense into itemizations to be paid and unpaid my example i didn t want the company to pay for my alcoholic beverage that accompanied my meal while travelling for business but my meal beverage was all on one receipt no easy way to do this
#
# expenses did not load properly caused a late submission of expense report
#
# not intuitive i was notified about an expense i incurred last week and came to the website and it did not show available expenses i had to find them this is more complicated than both cheers and global one
#
# it is very hard to upload receipts and has to be done multiple times
#
# i had to reload some of the receipt twice
#
# calendar error would not let me use actual travel dates and so i had to shift all dates to   weeks earlier what is that bug
#
# seems to be taking longer for emailed receipts to post
#
# Topic 11:
# didn didn t t wa know option meal import t know t work
#
# still learning the system bottom line is it is not intuitive between the whole choosing items saving etc
#
# terrible experience continuously crashing very slow
#
# i think it is still buggy
#
# se pierden   horas de trabajo para realizar una nota de gastos de una semana
#
# i finally not afraid of the app
#
# scroll down menu for types of expenses is not well tuned
#
# cannot find history of expenses submitted help does not work
#
# i cannot see the status of recent claims it says no active claims but there is one which is between approved and paid yet it does not show on concur
#
# the itemization is confusing
#
# veronica was very helpful in answering my questions about the report
#
# Topic 12:
# time multiple multiple time entry process consuming time consuming waste took waste time
#
# need either phone support or easy online help access
#
#   it would be helpful to be able to repeat the purpose and client name rather than typing the same thing a dozen times  it would be good to be able to edit the attendee list
#
# the navigation is not intuitive i had to ask a cowoker to show me how to select the proprer project i should be able to do this on my own
#
# this new version is not very user friendly especially when you are rerouted due to downed trees in a storm or other closed roads
#
# the system kept stalling whenever i wanted to attach the amex statement using the receipts attach receipt images dropdown so i ended up selecting one expense and appending it to that particular expense receipt image for it to upload
#
# it is slow it is not intuitive the most needed info is always hired somewhere
#
# not a user friendly tool for beginners i have spent on this report for more than   hours and i am still not sure if went through properly
#
# very helpful with any questions
#
# need to have tax id populated on itemized concepts on hotel charges
#
# system is very slow
#
# Topic 13:
# item line line item select expense item multiple duplicate list need individual
#
# got it down to a science now
#
# please add more us cities to your system also please enhance your system to allow for pre filling of vendor names once your start typing a name if they have been used before i e spectrum for internet service thank you
#
# no option to attach one page receipts to multiple expenses gas station location city why
#
# takes too long all kinds of issues where i can t get some expenses to move over to my report tried multiple times
#
# receipt server is slow to load receipts submitted by email
#
# very difficult to use steps unclear
#
# using concur did not show all hotel rates that were offered also i would like to see an all day option on flight times instead of the _ that is offered today
#
# acceptable performance
#
# not user friendly
#
# everything on this website takes so long to load and choose and there are too many glitches
#
# Topic 14:
# concur travel wa use s booking reservation flight book expense
#
# great and fast service
#
# this was my first expense report on the new system and it was extremely easy
#
# user interface could be better took time to figure out how to delete an expense from the report
#
# has to attach   times
#
# unclear how to add airline service fee when one fee applies to two separate flights
#
# audits are very very time consuming and exhaustive please contact me prior to any suspension to my credit card as i have a warning showing   days old expenses due to the time it s taking for audits and resubmitting
#
# i frequently see exceptions indicating that i have exceeded the daily meal allowance of     when the expense policy clearly says the daily allowance is
#
# inputting employee list is not user friendly
#
# quick and easy
#
# it took a couple of times for my receipt to attach
#
# Topic 15:
# don t don t clear know t know t clear t receipt think password
#
# it is frustrating trying to figure out on my own how to enter in hotel details when there is an issue i see the red explanation mark but don t know how to correct easily i end up entering information or expenses different ways until the error goes away i do not travel often and i run into this issue every time
#
# add more names of cities i ate at a restaurant in maricopa az which is the nearest location with restaurants to ntcna az but that town is not available so i had to select phoenix az that is not true information but it is the nearest other town
#
# la dã â marche est un peu fastidieuse et chronophage
#
# when a charge has uber in the title description it should automatically recognize it as a transportation charge the same is true for a charge from a parking garage listed in the description i waste my time categorizing these expenses when they should easily be recognized for what they are
#
# there s got to be a more efficient way than this
#
# the application is slow and it is not possible to add new attendees to an off site meal expense
#
# is not very clear how to add new employee to the concur employee when you create a new employee it does not show the selection concur employee took my   minutes to figure out it is not for sure intuitive cleber mattos cleber mattos gerdau com
#
# nice app easy to use
#
# difficult to use
#
# was very easy to follow and complete the expense report
#
# Topic 16:
# app phone phone app picture fix concur app app phone photo crash picture receipt
#
# need more city locations for gas purchases
#
# very frustrating when we book a flight thru concur but then do not receive the ticketed copy which shows the flight cost taxes service fee as we have to have receipts for all charges if you are gong to charge us a fee then send us the proper documentation showing the fees i booked   flights for my new hire both on swa i received his first flight final copy showing charge taxes and service fee i did not receive the final ticketed copy showing the cost taxes and service fee for the  nd flight trip to chicago also had a receipt for meal which concur would not accept the town name for the receipt so had to use the closest big city nearest thank you sharon frazier
#
# very very very much user unfriendly
#
# cannot find history of expenses submitted help does not work
#
# a copy function would be good for receipts since sometimes you have split the expense and with the current set up your only option is to re scan the image again
#
# my concern is with the process my expense report was returned for the following reason please change the expense type from office equipment hardware to materials and supplies for     and resubmit the report reason codes incorrect exp type selected why can t they just change the type on my behalf if they know the proper one
#
# user friendly
#
# attachments are causing a conflict in the report i have sent a help desk ticket but know one responded
#
# system performance and availability was poor otherwise no issues
#
# reporting is cumbersome and time consuming the allocation step seems redundant and the source of many issues each expense should have a single window with all applicable boxes and saved once
#
# Topic 17:
# expense report expense report hour took wa did took hour submit duplicate
#
# app doesnt work
#
# i had to re save all of the items on the web gui after i had already entered on the mobile client it was not a productive way to work
#
# i attached both pages of the receipt during my initial expense report entry one page did not add the other did this seems to be a bug
#
# got this down to a science now
#
# i m still troubled by some flaws like when i log personal car mileage and the mileage computed for the home to versus return home trips don t compute the same mileage total that makes no sense and it cheats me out of the proper reimbursement total
#
# easy to use
#
# when errors arise its difficult what exactly is the issue in addition i just had a report returned with several expense i submitted originally again it was hard to detect why it was returned i just resubmitted
#
# not overly user friendly and the import of receipt information is often wrong
#
# importing itineraries is not always easy and makes completing a report impossible without admin support very frustrating
#
# you have made this very simple thanks
#
# Topic 18:
# city missing major purchase big available accept location use list
#
# stop crashing
#
# could be easier to use if when in the mobile app you could allocate more info
#
# waiting days for american express receipts causes delays in filing reports
#
# need ability to have larger view of itemization screen
#
# some dow employee names would not show up in the people search and i had to enter them myself as guests
#
# the more i use this system the more i think the old system was better
#
# had trouble with a rail expense and system messages were not clear as to how to handle
#
# concur i very practical i appreciate its usefulness
#
# takes quite a bit of time
#
# easy to use
#
# Topic 19:
# glitch lot overall past long little need thank good app
#
# don t know where to attached pre trip approval
#
# site is so slow it took     hours
#
# i believe it would be a good option for all expenses booked with concur to be automatically imported receipts and all into concur vs having to find the email and upload transfer all of the information already known manually
#
# when ever filling the project id or project expense type a default value is getting posted the tool should clear all the fields and there should not be any default values in any field
#
# not very intuitive on how to add attendees to a dinner expense
#
# very cumbersome
#
# better reporting option for pulling report as per transaction date
#
# truly the worst software i ve experienced in years awful
#
# this system is clunky and time consuming a mobile version would be preferred thank you
#
# tbd

# %%
References:
    
1. https://medium.com/ml2vec/topic-modeling-is-an-unsupervised-learning-approach-to-clustering-documents-to-discover-topics-fdfbf30e27df
2.
